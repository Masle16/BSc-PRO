# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
#from tensorflow.keras.layers import Conv2D
#from tensorflow.keras.layers import MaxPooling2D
#from tensorflow.keras.layers import BatchNormalization
#from tensorflow.keras.layers import Dropout, Flatten, Dense
import matplotlib.pyplot as plt

# %% [markdown]
# <b>Path to resources</b>

# %%
train_path = '../potato_and_catfood/train'
valid_path = '../potato_and_catfood/valid'
test_path = '../potato_and_catfood/test'

# %% [markdown]
# <b>ImageDataGenerator.flow_from_directory(directory, target_size, classes, batch_size)</b>
# <ul>
#     <li>directory:    path to directory. All PNG, JPG, BMP, PPM, TIF files in each subdirectory will be included in the generator.</li>
#     <li>target_size:  (height, width) that the images will be resized to.</li>
#     <li>classes:      Will import from subdirectories in classes.</li>
#     <li>batch_size:   Size of batches of data.</li>
# </ul>

# %%
train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(720,1280), classes=['potato', 'catfood'], batch_size = 10)
valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(720,1280), classes=['potato', 'catfood'], batch_size = 4)
test_batches  = ImageDataGenerator().flow_from_directory(test_path, target_size=(720,1280), classes=['potato', 'catfood'], batch_size = 4)
# Out:
# Found 431 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
imgs, labels = next(train_batches)

# %%
for i in range(imgs.shape[0]):
    plt.figure(i)
    if (labels[i][0] == 1.0):
        plt.title("Potato, image: " + str(i) )
    if (labels[i][1] == 1.0):
        plt.title("Catfood, image: " + str(i) )
    plt.imshow(imgs[i].astype(np.uint8))

# %%
height = 720
width = 1280
depth = 3     # amount of channels

input_shape = (height, width, depth)

# %% [markdown]
# <h1>Plot of 1280x720 -> 224x224</h1>

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
train_path = '../potato_and_catfood/train'
valid_path = '../potato_and_catfood/valid'
test_path = '../potato_and_catfood/test'

train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(224,224), classes=['potato', 'catfood', 'table'], batch_size = 10)
# Out:
# Found 506 images belonging to 3 classes.

# %%
imgs, labels = next(train_batches)

for i in range(imgs.shape[0]):
    plt.figure(i)
    if (labels[i][0] == 1.0):
        plt.title("Potato, image: " + str(i) )
    if (labels[i][1] == 1.0):
        plt.title("Catfood, image: " + str(i) )
    if (labels[i][2] == 1.0):
        plt.title("Table, image: " + str(i) )
    plt.imshow(imgs[i].astype(np.uint8))

# %% [markdown]
# <h1>Images for thesis</h1>

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-7abb00e2f4b5> in <module>()
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3 from keras.preprocessing.image import ImageDataGenerator
#       4 import matplotlib.pyplot as plt
#
# /home/mikkel/anaconda2/envs/BPRO/lib/python2.7/site-packages/tensorflow/__init__.py in <module>()
#      22
#      23 # pylint: disable=wildcard-import
# ---> 24 from tensorflow.python import *
#      25 # pylint: enable=wildcard-import
#      26
#
# /home/mikkel/anaconda2/envs/BPRO/lib/python2.7/site-packages/tensorflow/python/__init__.py in <module>()
#      49 import numpy as np
#      50
# ---> 51 from tensorflow.python import pywrap_tensorflow
#      52
#      53 # Protocol buffers
#
# ImportError: cannot import name pywrap_tensorflow

# %%
img_path = '../reportDataAugment.jpg'

# %%
im = plt.imread(img_path)

#Dictionary for param
param = {
    'flip_horizontal': True
}

horizontal = ImageDataGenerator().apply_transform(im, param)

param = {
    'flip_vertical': True
}

vertical = ImageDataGenerator().apply_transform(im, param)

param = {
    'brightness': 0.65
}

dark = ImageDataGenerator().apply_transform(im, param)

param = {
    'brightness': 1.35
}

light = ImageDataGenerator().apply_transform(im, param)

plt.subplot(5, 1, 1)
plt.title('Original image')
plt.imshow(im)

plt.subplot(5, 1, 2)
plt.title('Vertical flip')
plt.imshow(vertical)

plt.subplot(5, 1, 3)
plt.imshow(horizontal)
plt.title('Horizontal flip')
plt.show()

plt.subplot(5, 1, 4)
plt.imshow(dark.astype(np.uint8))
plt.title('Darker')
plt.show()

plt.subplot(5, 1, 5)
plt.imshow(light.astype(np.uint8))
plt.title('Lighter')
plt.show()

# %%
from PIL import Image
img = Image.fromarray(dark.astype(np.uint8))
img.save("../DataAugment/dark.jpeg")

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
#img_path = '../reportDataAugment.jpg'
img_path = '../tessst.jpg'

plt.figure(1)
im = plt.imread(img_path)
plt.imshow(im)

#Dictionary for param
param = {
    'theta': 40
}
edit = ImageDataGenerator().apply_transform(im, param)
plt.figure(2)
plt.imshow(edit)
